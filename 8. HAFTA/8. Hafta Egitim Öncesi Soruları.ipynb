# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
ürün_adi= input("Ürün adını giriniz:")
ürün_fiyati=input("Ürünün fiyat bilgisini giriniz:")

def ekle(ürün_adi,ürün_fiyati):
    with open("urunler.txt" , "a") as dosya:
        dosya.write(f"ad: {ürün_adi} fiyat: {ürün_fiyati}\n")
                
ekle(ürün_adi,ürün_fiyati)

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
eski_kelime= input("Değiştirmek istediğiniz kelimeyi giriniz:")
yeni_kelime= input("Yeni kelimeyi giriniz:")

def değiştir(urunler):
    with open(urunler,"r",encoding='utf-8') as dosya:
        data = dosya.read()
        yeni_data = data.replace(eski_kelime, yeni_kelime)
    with open(urunler,"w",encoding='utf-8') as dosya:
        dosya.write(yeni_data)
print(f"{"eski_kelime"} kelimesi {"yeni_kelime"} olarak değiştirildi." )

değiştir("urunler.txt")
# Out:
# eski_kelime kelimesi yeni_kelime olarak değiştirildi.

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
class Vehicle:
    def __init__(self, Name, Speed, Miliage):
        self.name=Name
        self.speed=Speed
        self.milliage=Miliage

class Bus(Vehicle):
    def __str__(self):
        return "Otobüs"
    
okul_otobüsü = Bus( "Volvo", 180,200000)

print(f"İsim:{okul_otobüsü.name}\nHız:{okul_otobüsü.speed}")
print(okul_otobüsü)
# Out:
# İsim:Volvo
# Hız:180
# Otobüs
