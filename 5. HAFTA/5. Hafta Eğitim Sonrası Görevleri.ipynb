# %% [markdown]
# # Problem 1
#
# Fizikte, bir nesnenin sabit ivmeyle hareket ederken son hızını
# (veya hızını) bulmak için aşağıdaki denklem kullanılabilir:
# ```
# vf = vi + at
# burada:
# vf= son hız
# vi= ilk hız
# a= hızlanma
# t= zaman
# ```
# İlk hız, ivme ve zaman verildiğinde, son hızı döndürecek bir fonksiyon yazın.

# %%
def son_hız(lk_hız,ivme,zaman):
    
    son_hız= ilk_hız+(ivme*zaman)
    return son_hız

ilk_hız= int(input("İlk hızı giriniz:"))
ivme = int(input("İvmeyi giriniz:"))
zaman= int(input("Süreyi giriniz:"))

son_hız(ilk_hız, ivme, zaman)
# Out:
# 12

# %% [markdown]
# # Problem 2
#
# 1'den 1000'e kadar olan sayılardan mükemmel sayı olanları ekrana yazdırın. Bunun için bir sayının mükemmel olup olmadığını dönen bir tane fonksiyon yazın.
#
# Bir sayının bölenlerinin toplamı kendine eşitse bu sayı mükemmel bir sayıdır. Örnek olarak 6 mükemmel bir sayıdır (1 + 2 + 3 = 6).

# %%
def mükemmel_sayi(sayi):
   toplam = 0
   for i in range (1 , sayi):
    if sayi % i == 0:
       toplam += i
   return sayi == toplam
       
for sayi in range (1,1001):
  if mükemmel_sayi(sayi):
    print(sayi)
# Out:
# 6
# 28
# 496

# %% [markdown]
# # Problem 3
#
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

# %%
def pisagor():
    for a in range(1, 101):
        for b in range(1, 101):
            for c in range(1, 101):
                if a**2 == b**2 + c**2 and a <= 100:
                    print(f"{a} {b} {c} pisagor üçgenidir.")

pisagor()
# Out:
# 5 3 4 pisagor üçgenidir.
# 5 4 3 pisagor üçgenidir.
# 10 6 8 pisagor üçgenidir.
# 10 8 6 pisagor üçgenidir.
# 13 5 12 pisagor üçgenidir.
# 13 12 5 pisagor üçgenidir.
# 15 9 12 pisagor üçgenidir.
# 15 12 9 pisagor üçgenidir.
# 17 8 15 pisagor üçgenidir.
# 17 15 8 pisagor üçgenidir.
# 20 12 16 pisagor üçgenidir.
# 20 16 12 pisagor üçgenidir.
# 25 7 24 pisagor üçgenidir.
# 25 15 20 pisagor üçgenidir.
# 25 20 15 pisagor üçgenidir.
# 25 24 7 pisagor üçgenidir.
# 26 10 24 pisagor üçgenidir.
# 26 24 10 pisagor üçgenidir.
# 29 20 21 pisagor üçgenidir.
# 29 21 20 pisagor üçgenidir.
# 30 18 24 pisagor üçgenidir.
# 30 24 18 pisagor üçgenidir.
# 34 16 30 pisagor üçgenidir.
# 34 30 16 pisagor üçgenidir.
# 35 21 28 pisagor üçgenidir.
# 35 28 21 pisagor üçgenidir.
# 37 12 35 pisagor üçgenidir.
# 37 35 12 pisagor üçgenidir.
# 39 15 36 pisagor üçgenidir.
# 39 36 15 pisagor üçgenidir.
# 40 24 32 pisagor üçgenidir.
# 40 32 24 pisagor üçgenidir.
# 41 9 40 pisagor üçgenidir.
# 41 40 9 pisagor üçgenidir.
# 45 27 36 pisagor üçgenidir.
# 45 36 27 pisagor üçgenidir.
# 50 14 48 pisagor üçgenidir.
# 50 30 40 pisagor üçgenidir.
# 50 40 30 pisagor üçgenidir.
# 50 48 14 pisagor üçgenidir.
# 51 24 45 pisagor üçgenidir.
# 51 45 24 pisagor üçgenidir.
# 52 20 48 pisagor üçgenidir.
# 52 48 20 pisagor üçgenidir.
# 53 28 45 pisagor üçgenidir.
# 53 45 28 pisagor üçgenidir.
# 55 33 44 pisagor üçgenidir.
# 55 44 33 pisagor üçgenidir.
# 58 40 42 pisagor üçgenidir.
# 58 42 40 pisagor üçgenidir.
# 60 36 48 pisagor üçgenidir.
# 60 48 36 pisagor üçgenidir.
# 61 11 60 pisagor üçgenidir.
# 61 60 11 pisagor üçgenidir.
# 65 16 63 pisagor üçgenidir.
# 65 25 60 pisagor üçgenidir.
# 65 33 56 pisagor üçgenidir.
# 65 39 52 pisagor üçgenidir.
# 65 52 39 pisagor üçgenidir.
# 65 56 33 pisagor üçgenidir.
# 65 60 25 pisagor üçgenidir.
# 65 63 16 pisagor üçgenidir.
# 68 32 60 pisagor üçgenidir.
# 68 60 32 pisagor üçgenidir.
# 70 42 56 pisagor üçgenidir.
# 70 56 42 pisagor üçgenidir.
# 73 48 55 pisagor üçgenidir.
# 73 55 48 pisagor üçgenidir.
# 74 24 70 pisagor üçgenidir.
# 74 70 24 pisagor üçgenidir.
# 75 21 72 pisagor üçgenidir.
# 75 45 60 pisagor üçgenidir.
# 75 60 45 pisagor üçgenidir.
# 75 72 21 pisagor üçgenidir.
# 78 30 72 pisagor üçgenidir.
# 78 72 30 pisagor üçgenidir.
# 80 48 64 pisagor üçgenidir.
# 80 64 48 pisagor üçgenidir.
# 82 18 80 pisagor üçgenidir.
# 82 80 18 pisagor üçgenidir.
# 85 13 84 pisagor üçgenidir.
# 85 36 77 pisagor üçgenidir.
# 85 40 75 pisagor üçgenidir.
# 85 51 68 pisagor üçgenidir.
# 85 68 51 pisagor üçgenidir.
# 85 75 40 pisagor üçgenidir.
# 85 77 36 pisagor üçgenidir.
# 85 84 13 pisagor üçgenidir.
# 87 60 63 pisagor üçgenidir.
# 87 63 60 pisagor üçgenidir.
# 89 39 80 pisagor üçgenidir.
# 89 80 39 pisagor üçgenidir.
# 90 54 72 pisagor üçgenidir.
# 90 72 54 pisagor üçgenidir.
# 91 35 84 pisagor üçgenidir.
# 91 84 35 pisagor üçgenidir.
# 95 57 76 pisagor üçgenidir.
# 95 76 57 pisagor üçgenidir.
# 97 65 72 pisagor üçgenidir.
# 97 72 65 pisagor üçgenidir.
# 100 28 96 pisagor üçgenidir.
# 100 60 80 pisagor üçgenidir.
# 100 80 60 pisagor üçgenidir.
# 100 96 28 pisagor üçgenidir.

# %% [markdown]
# # Problem 4
#
# Bir duvar boyamaya karar verdiniz. Boya kutusunun üzerindeki talimatta, 1 kutu boyanın 5 metrekarelik bir duvarı boyayabileceği yazıyor. Rastgele bir duvar yüksekliği ve genişliği verildiğinde, kaç kutu boya satın almanız gerektiğini hesaplayın.
#
# kutu sayısı = (duvar yüksekliği * duvar genişliği) ÷ kutu başına kaplama.
#
# örneğin Yükseklik = 2, Genişlik = 4, Kaplama = 5
#
# kutu sayısı = (2 * 4) ÷ 5 = 1.6
#
# Ancak bir kutu boyanın 0,6'sını satın alamayacağınız için, sonuç 2 kutuya yuvarlanmalıdır .

# %%
import math

def kutu_sayisi (yükseklik,genişlik,kaplama):
    kutu_sayisi = math.ceil((yükseklik * genişlik) / kaplama)
    return kutu_sayisi

kutu_sayisi(2,4,5)
# Out:
# 2

# %% [markdown]
# # Problem 5
#
# Bir kelimedeki ünlü ve ünsüz harfleri sayan bir fonksiyon yazınız.

# %% [markdown]
# # Problem 6
#
# Verilen bir listeden çift sayıları yazdıran bir fonksiyon yazınız.

# %%
def çift_sayilar(liste):
    çift= []
    for sayi in liste:
        if sayi % 2 == 0:
            çift.append(sayi)
    return çift

print(çift_sayilar([1, 2, 3, 4, 5, 6]))  # Çıktı: [2, 4, 6]
# Out:
# [2, 4, 6]

# %% [markdown]
# # Problem 7
#
# 0'dan 10'a kadar olan sayıların toplamını hesaplayan özyinelemeli (Recursive Function) bir fonksiyon oluşturan bir fonksiyon yazınız.
#
# Özyinelemeli (Recursive Function) bir işlev, kendini tekrar tekrar çağıran bir işlevdir.

# %%
def toplam():
    toplam = 0
    for i in range (0,11):
        toplam += i
    return toplam

toplam()
# Out:
# 55
